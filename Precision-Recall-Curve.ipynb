# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pickle.load(open("precisionRecallCurve.pkl", "rb"))

# %%
print(data)
# Out:
# [(0.0, 0.0), (0.1388888888888889, 0.03125), (0.16296296296296298, 0.055), (0.18611111111111112, 0.08375), (0.18888888888888888, 0.10625), (0.19074074074074074, 0.12875), (0.18253968253968253, 0.14375), (0.1763888888888889, 0.15875), (0.16913580246913582, 0.17125), (0.16555555555555557, 0.18625), (0.1606060606060606, 0.19875), (0.15555555555555556, 0.21), (0.15726495726495726, 0.23), (0.15158730158730158, 0.23875), (0.14444444444444443, 0.24375), (0.14027777777777778, 0.2525), (0.13725490196078433, 0.2625), (0.13209876543209875, 0.2675), (0.12748538011695906, 0.2725), (0.125, 0.28125), (0.12169312169312169, 0.2875), (0.12121212121212122, 0.3), (0.11835748792270531, 0.30625), (0.11574074074074074, 0.3125), (0.11333333333333333, 0.31875), (0.10982905982905983, 0.32125), (0.10617283950617284, 0.3225), (0.10436507936507937, 0.32875), (0.10191570881226053, 0.3325), (0.09925925925925926, 0.335), (0.0960573476702509, 0.335), (0.09340277777777778, 0.33625), (0.09090909090909091, 0.3375), (0.08986928104575163, 0.34375), (0.08793650793650794, 0.34625), (0.0867283950617284, 0.35125), (0.08528528528528528, 0.355), (0.08421052631578947, 0.36), (0.0829059829059829, 0.36375), (0.08194444444444444, 0.36875), (0.08048780487804878, 0.37125), (0.07936507936507936, 0.375), (0.07803617571059432, 0.3775), (0.07702020202020202, 0.38125), (0.07604938271604939, 0.385), (0.0751207729468599, 0.38875), (0.07446808510638298, 0.39375), (0.07314814814814814, 0.395), (0.07233560090702948, 0.39875), (0.07133333333333333, 0.40125), (0.07167755991285403, 0.41125), (0.07094017094017094, 0.415), (0.07044025157232704, 0.42), (0.06954732510288066, 0.4225), (0.06868686868686869, 0.425), (0.06785714285714285, 0.4275), (0.06666666666666667, 0.4275), (0.06609195402298851, 0.43125), (0.06516007532956686, 0.4325), (0.06444444444444444, 0.435), (0.06375227686703097, 0.4375), (0.06290322580645161, 0.43875), (0.06261022927689594, 0.44375), (0.06197916666666667, 0.44625), (0.061196581196581196, 0.4475), (0.06060606060606061, 0.45), (0.05970149253731343, 0.45), (0.05915032679738562, 0.4525), (0.05877616747181964, 0.45625), (0.058095238095238096, 0.4575), (0.057746478873239436, 0.46125), (0.05694444444444444, 0.46125), (0.0563165905631659, 0.4625), (0.056006006006006005, 0.46625), (0.05525925925925926, 0.46625), (0.05453216374269006, 0.46625), (0.05382395382395382, 0.46625), (0.053418803418803416, 0.46875), (0.053164556962025315, 0.4725), (0.0525, 0.4725), (0.05198902606310014, 0.47375), (0.051355013550135505, 0.47375), (0.050870147255689425, 0.475), (0.0503968253968254, 0.47625), (0.050065359477124184, 0.47875), (0.04961240310077519, 0.48), (0.04904214559386973, 0.48), (0.048484848484848485, 0.48), (0.0484394506866417, 0.485), (0.048024691358024695, 0.48625), (0.047496947496947495, 0.48625), (0.04722222222222222, 0.48875), (0.04683393070489845, 0.49), (0.046335697399527184, 0.49), (0.04584795321637427, 0.49), (0.04560185185185185, 0.4925), (0.04513172966781214, 0.4925), (0.04478458049886622, 0.49375), (0.044444444444444446, 0.495), (0.044222222222222225, 0.4975), (0.043894389438943894, 0.49875), (0.0434640522875817, 0.49875), (0.043042071197411005, 0.49875), (0.042735042735042736, 0.5), (0.042328042328042326, 0.5), (0.04213836477987421, 0.5025), (0.041848390446521284, 0.50375), (0.04156378600823045, 0.505), (0.04138634046890927, 0.5075), (0.04111111111111111, 0.50875), (0.04094094094094094, 0.51125), (0.040674603174603176, 0.5125), (0.04031465093411996, 0.5125), (0.040058479532163745, 0.51375), (0.03971014492753623, 0.51375), (0.03946360153256705, 0.515), (0.03922127255460589, 0.51625), (0.03888888888888889, 0.51625), (0.038562091503267976, 0.51625), (0.03851851851851852, 0.52), (0.03820018365472911, 0.52), (0.03788706739526412, 0.52), (0.03766937669376694, 0.52125), (0.037365591397849465, 0.52125), (0.03715555555555555, 0.5225), (0.03686067019400353, 0.5225), (0.03657042869641295, 0.5225), (0.036284722222222225, 0.5225), (0.03608957795004307, 0.52375), (0.035897435897435895,  ...

# %%
ydata = np.empty(len(data))
xdata = np.empty(len(data))

for i in range(len(data)):
    ydata[i] = data[i][0]
    xdata[i] = data[i][1]

print(ydata)
print(xdata)
# Out:
# [0.         0.13888889 0.16296296 ... 0.00258234 0.00258148 0.00258062]
# [0.      0.03125 0.055   ... 0.87125 0.87125 0.87125]

# %%
maxind = np.argmax(ydata)
print(maxind)

plt.plot(xdata, ydata)
plt.plot(xdata[maxind], ydata[maxind], "rx")
plt.text(xdata[maxind]+0.05, ydata[maxind], "Max precision of " + str(ydata[maxind]) + " at 5 recalled items")
plt.ylabel("Precision")
plt.xlabel("Recall")
plt.show()
# Out:
# 5
